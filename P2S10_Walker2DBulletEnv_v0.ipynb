# %% [markdown]
# <a href="https://colab.research.google.com/github/AmulPatil/Reinforcement-learning/blob/master/P2S10_Walker2DBulletEnv_v0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twin-Delayed DDPG
#
# Complete credit goes to this [awesome Deep Reinforcement Learning 2.0 Course on Udemy](https://www.udemy.com/course/deep-reinforcement-learning/) for the code.

# %% [markdown]
# ## Installing the packages

# %%
# !pip install pybullet
# Out:
# Collecting pybullet
#   Downloading https://files.pythonhosted.org/packages/1e/f5/3d4b55403e40de7892c2f091d95c1db4879204ad8d5fe91e575f850c892e/pybullet-2.7.9.tar.gz (83.7MB)
#      |████████████████████████████████| 83.7MB 57kB/s
# Building wheels for collected packages: pybullet
#   Building wheel for pybullet (setup.py) ... done
#   Created wheel for pybullet: filename=pybullet-2.7.9-cp36-cp36m-linux_x86_64.whl size=95748595 sha256=f32089288972ca5d5e0a3d8af3ae3abe8607004b157f6b7f50c7cb357943e04b
#   Stored in directory: /root/.cache/pip/wheels/78/f8/14/4db8932eb7c73725541a93a659efbf9757a935bd47c09d612d
# Successfully built pybullet
# Installing collected packages: pybullet
# Successfully installed pybullet-2.7.9

# %% [markdown]
# ## Importing the libraries

# %%
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import pybullet_envs
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from gym import wrappers
from torch.autograd import Variable
from collections import deque

# %% [markdown]
# ## Step 1: We initialize the Experience Replay memory

# %%
class ReplayBuffer(object):

  def __init__(self, max_size=1e6):
    self.storage = []
    self.max_size = max_size
    self.ptr = 0

  def add(self, transition):
    if len(self.storage) == self.max_size:
      self.storage[int(self.ptr)] = transition
      self.ptr = (self.ptr + 1) % self.max_size
    else:
      self.storage.append(transition)
      self.ptr = (self.ptr + 1) % self.max_size

  def sample(self, batch_size):
    ind = np.random.randint(0, len(self.storage), size=batch_size)
    batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = [], [], [], [], []
    for i in ind: 
      state, next_state, action, reward, done = self.storage[i]
      batch_states.append(np.array(state, copy=False))
      batch_next_states.append(np.array(next_state, copy=False))
      batch_actions.append(np.array(action, copy=False))
      batch_rewards.append(np.array(reward, copy=False))
      batch_dones.append(np.array(done, copy=False))
    return np.array(batch_states), np.array(batch_next_states), np.array(batch_actions), np.array(batch_rewards).reshape(-1, 1), np.array(batch_dones).reshape(-1, 1)

# %% [markdown]
# ## Step 2: We build one neural network for the Actor model and one neural network for the Actor target

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x))
    return x

# %% [markdown]
# ## Step 3: We build two neural networks for the two Critic models and two neural networks for the two Critic targets

# %%
class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# %% [markdown]
# ## Steps 4 to 15: Training Process

# %%
# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state)
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

# %% [markdown]
# ## We make a function that evaluates the policy by calculating its average reward over 10 episodes

# %%
def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

# %% [markdown]
# ## We set the parameters

# %%
env_name = "Walker2DBulletEnv-v0" # Name of a environment (set it to any Continous environment you want)
seed = 0 # Random seed number
start_timesteps = 1e4 # Number of iterations/timesteps before which the model randomly chooses an action, and after which it starts to use the policy network
eval_freq = 5e3 # How often the evaluation step is performed (after how many timesteps)
max_timesteps = 5e5 # Total number of iterations/timesteps
save_models = True # Boolean checker whether or not to save the pre-trained model
expl_noise = 0.1 # Exploration noise - STD value of exploration Gaussian noise
batch_size = 100 # Size of the batch
discount = 0.99 # Discount factor gamma, used in the calculation of the total discounted reward
tau = 0.005 # Target network update rate
policy_noise = 0.2 # STD of Gaussian noise added to the actions for the exploration purposes
noise_clip = 0.5 # Maximum value of the Gaussian noise added to the actions (policy)
policy_freq = 2 # Number of iterations to wait before the policy network (Actor model) is updated

# %% [markdown]
# ## We create a file name for the two saved models: the Actor and Critic models

# %%
file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")
# Out:
# ---------------------------------------
# Settings: TD3_Walker2DBulletEnv-v0_0
# ---------------------------------------

# %% [markdown]
# ## We create a folder inside which will be saved the trained models

# %%
if not os.path.exists("./results"):
  os.makedirs("./results")
if save_models and not os.path.exists("./pytorch_models"):
  os.makedirs("./pytorch_models")

# %% [markdown]
# ## We create the PyBullet environment

# %%
env = gym.make(env_name)
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# ## We set seeds and we get the necessary information on the states and actions in the chosen environment

# %%
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %% [markdown]
# ## We create the policy network (the Actor model)

# %%
policy = TD3(state_dim, action_dim, max_action)

# %% [markdown]
# [link text](https://)## We create the Experience Replay memory

# %%
replay_buffer = ReplayBuffer()

# %% [markdown]
# ## We define a list where all the evaluation results over 10 episodes are stored

# %%
evaluations = [evaluate_policy(policy)]
# Out:
# ---------------------------------------
# Average Reward over the Evaluation Step: 264.967772
# ---------------------------------------

# %% [markdown]
# ## We create a new folder directory in which the final results (videos of the agent) will be populated

# %%
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path
work_dir = mkdir('exp', 'brs')
monitor_dir = mkdir(work_dir, 'monitor')
max_episode_steps = env._max_episode_steps
save_env_vid = False
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()

# %% [markdown]
# ## We initialize the variables

# %%
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()

# %% [markdown]
# ## Training

# %%
max_timesteps = 500000
# We start the main loop over 500,000 timesteps
while total_timesteps < max_timesteps:
  
  # If the episode is done
  if done:

    # If we are not at the very beginning, we start the training process of the model
    if total_timesteps != 0:
      print("Total Timesteps: {} Episode Num: {} Reward: {}".format(total_timesteps, episode_num, episode_reward))
      policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)

    # We evaluate the episode and we save the policy
    if timesteps_since_eval >= eval_freq:
      timesteps_since_eval %= eval_freq
      evaluations.append(evaluate_policy(policy))
      policy.save(file_name, directory="./pytorch_models")
      np.save("./results/%s" % (file_name), evaluations)
    
    # When the training step is done, we reset the state of the environment
    obs = env.reset()
    
    # Set the Done to False
    done = False
    
    # Set rewards and episode timesteps to zero
    episode_reward = 0
    episode_timesteps = 0
    episode_num += 1
  
  # Before 10000 timesteps, we play random actions
  if total_timesteps < start_timesteps:
    action = env.action_space.sample()
  else: # After 10000 timesteps, we switch to the model
    action = policy.select_action(np.array(obs))
    # If the explore_noise parameter is not 0, we add noise to the action and we clip it
    if expl_noise != 0:
      action = (action + np.random.normal(0, expl_noise, size=env.action_space.shape[0])).clip(env.action_space.low, env.action_space.high)
  
  # The agent performs the action in the environment, then reaches the next state and receives the reward
  new_obs, reward, done, _ = env.step(action)
  
  # We check if the episode is done
  done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
  
  # We increase the total reward
  episode_reward += reward
  
  # We store the new transition into the Experience Replay memory (ReplayBuffer)
  replay_buffer.add((obs, new_obs, action, reward, done_bool))

  # We update the state, the episode timestep, the total timesteps, and the timesteps since the evaluation of the policy
  obs = new_obs
  episode_timesteps += 1
  total_timesteps += 1
  timesteps_since_eval += 1

# We add the last policy evaluation to our list of evaluations and we save our model
evaluations.append(evaluate_policy(policy))
if save_models: policy.save("%s" % (file_name), directory="./pytorch_models")
np.save("./results/%s" % (file_name), evaluations)
# Out:
# Total Timesteps: 13 Episode Num: 1 Reward: 15.239908197701153
# Total Timesteps: 29 Episode Num: 2 Reward: 18.081697686265393
# Total Timesteps: 55 Episode Num: 3 Reward: 22.475092859803407
# Total Timesteps: 65 Episode Num: 4 Reward: 14.434271721456025
# Total Timesteps: 78 Episode Num: 5 Reward: 15.778268094391388
# Total Timesteps: 96 Episode Num: 6 Reward: 20.08090508088499
# Total Timesteps: 103 Episode Num: 7 Reward: 12.511870766084757
# Total Timesteps: 120 Episode Num: 8 Reward: 17.41426776696753
# Total Timesteps: 833 Episode Num: 55 Reward: 18.634527628251817
# Total Timesteps: 848 Episode Num: 56 Reward: 14.588911238696893
# Total Timesteps: 867 Episode Num: 57 Reward: 19.791219128880762
# Total Timesteps: 879 Episode Num: 58 Reward: 13.037616129135131
# Total Timesteps: 901 Episode Num: 59 Reward: 21.8940281166113
# Total Timesteps: 910 Episode Num: 60 Reward: 14.000935730503986
# Total Timesteps: 918 Episode Num: 61 Reward: 13.020124248747015
# Total Timesteps: 936 Episode Num: 62 Reward: 18.71193836450984
# Total Timesteps: 958 Episode Num: 63 Reward: 23.417297866391888
# Total Timesteps: 968 Episode Num: 64 Reward: 13.4036770805571
# Total Timesteps: 983 Episode Num: 65 Reward: 17.202495887543776
# Total Timesteps: 998 Episode Num: 66 Reward: 17.948533716789093
# Total Timesteps: 1025 Episode Num: 67 Reward: 25.165986863945726
# Total Timesteps: 1034 Episode Num: 68 Reward: 14.051142719406924
# Total Timesteps: 1043 Episode Num: 69 Reward: 13.2458549444651
# Total Timesteps: 1052 Episode Num: 70 Reward: 14.18517094745912
# Total Timesteps: 1067 Episode Num: 71 Reward: 13.411311921350718
# Total Timesteps: 1086 Episode Num: 72 Reward: 19.88885190769506
# Total Timesteps: 1098 Episode Num: 73 Reward: 15.298851050082884
# Total Timesteps: 1105 Episode Num: 74 Reward: 13.011374100811372
# Total Timesteps: 1113 Episode Num: 75 Reward: 13.964653946291945
# Total Timesteps: 1131 Episode Num: 76 Reward: 19.693328997821663
# Total Timesteps: 1144 Episode Num: 77 Reward: 17.726986893139838
# Total Timesteps: 1158 Episode Num: 78 Reward: 17.526778651923816
# Total Timesteps: 1171 Episode Num: 79 Reward: 17.07730976046587
# Total Timesteps: 1182 Episode Num: 80 Reward: 16.39696142366738
# Total Timesteps: 1203 Episode Num: 81 Reward: 21.568434700445504
# Total Timesteps: 1217 Episode Num: 82 Reward: 17.358714631294426
# Total Timesteps: 1234 Episode Num: 83 Reward: 15.926317486436162
# Total Timesteps: 1260 Episode Num: 84 Reward: 23.16737243945245
# Total Timesteps: 1276 Episode Num: 85 Reward: 18.331940252357164
# Total Timesteps: 1287 Episode Num: 86 Reward: 16.016478299975276
# Total Timesteps: 1298 Episode Num: 87 Reward: 15.586035214446017
# Total Timesteps: 1316 Episode Num: 88 Reward: 19.565266079652062
# Total Timesteps: 1323 Episode Num: 89 Reward: 12.498038533741783
# Total Timesteps: 1340 Episode Num: 90 Reward: 19.484580955156705
# Total Timesteps: 1352 Episode Num: 91 Reward: 15.886381180933675
# Total Timesteps: 1368 Episode Num: 92 Reward: 14.96438381363259
# Total Timesteps: 1375 Episode Num: 93 Reward: 12.77509573168063
# Total Timesteps: 1391 Episode Num: 94 Reward: 19.131981264842036
# Total Timesteps: 1400 Episode Num: 95 Reward: 14.172127939060736
# Total Timesteps: 1421 Episode Num: 96 Reward: 18.303810951866033
# Total Timesteps: 1432 Episode Num: 97 Reward: 15.229218136053529
# Total Timesteps: 1452 Episode Num: 98 Reward: 22.403955057925483
# Total Timesteps: 1462 Episode Num: 99 Reward: 14.179118696307704
# Total Timesteps: 1481 Episode Num: 100 Reward: 17.240482270794747
# Total Timesteps: 1493 Episode Num: 101 Reward: 16.6636119900475
# Total Timesteps: 1513 Episode Num: 102 Reward: 19.410515335251695
# Total Timesteps: 1525 Episode Num: 103 Reward: 14.681548532845044
# Total Timesteps: 1538 Episode Num: 104 Reward: 16.52515997529408
# Total Timesteps: 1555 Episode Num: 105 Reward: 17.86374455629703
# Total Timesteps: 1571 Episode Num: 106 Reward: 17.67670690194209
# Total Timesteps: 1594 Episode Num: 107 Reward: 24.01207897487184
# Total Timesteps: 1607 Episode Num: 108 Reward: 15.312111035975974
# Total Timesteps: 1616 Episode Num: 109 Reward: 13.745050488242121
# Total Timesteps: 1635 Episode Num: 110 Reward: 16.148905986374302
# Total Timesteps: 1647 Episode Num: 111 Reward: 15.238952123872876
# Total Timesteps: 1660 Episode Num: 112 Reward: 17.496656600582355
# Total Timesteps: 1680 Episode Num: 113 Reward: 24.00366915057966
# Total Timesteps: 1691 Episode Num: 114 Reward: 15.98376435883838
# Total Timesteps: 1709 Episode Num: 115 Reward: 17.998291376320417
# Total Timesteps: 1726 Episode Num: 116 Reward: 16.0669828490325
# Total Timesteps: 1740 Episode Num: 117 Reward: 17.39723482014815
# Total Timesteps: 1755 Episode Num: 118 Reward: 17.2593843154129
# Total Timesteps: 1765 Episode Num: 119 Reward: 14.051495655174948
# Total Timesteps: 1772 Episode Num: 120 Reward: 11.650415177967806
# Total Timesteps: 1782 Episode Num: 121 Reward: 13.615070928739442
# Total Timesteps: 1800 Episode Num: 122 Reward: 20.27794143163337
# Total Timesteps: 1819 Episode Num: 123 Reward: 20.378376057679997
# Total Timesteps: 1832 Episode Num: 124 Reward: 17.38670338704978
# Total Timesteps: 1851 Episode Num: 125 Reward: 19.82038722584985
# Total Timesteps: 1859 Episode Num: 126 Reward: 11.769667762091556
# Total Timesteps: 1869 Episode Num: 127 Reward: 13.971847898578565
# Total Timesteps: 1882 Episode Num: 128 Reward: 15.056501864521124
# Total Timesteps: 1893 Episode Num: 129 Reward: 15.768505157645267
# Total Timesteps: 1905 Episode Num: 130 Reward: 17.831899027396865
# Total Timesteps: 1922 Episode Num: 131 Reward: 17.71480699553649
# Total Timesteps: 1940 Episode Num: 132 Reward: 19.902248629226232
# Total Timesteps: 1965 Episode Num: 133 Reward: 24.38796273178304
# Total Timesteps: 1975 Episode Num: 134 Reward: 14.969320108201646
# Total Timesteps: 1986 Episode Num: 135 Reward: 14.565255893162975
# Total Timesteps: 2007 Episode Num: 136 Reward: 18.48964433343645
# Total Timesteps: 2020 Episode Num: 137 Reward: 18.334174130794413
# Total Timesteps: 2032 Episode Num: 138 Reward: 16.103407463784972
# Total Timesteps: 2052 Episode Num: 139 Reward: 21.224469881813278
# Total Timesteps: 2066 Episode Num: 140 Reward: 16.154627349649672
# Total Timesteps: 2081 Episode Num: 141 Reward: 17.892679904958637
# Total Timesteps: 2096 Episode Num: 142 Reward: 18.239082476405017
# Total Timesteps: 2111 Episode Num: 143 Reward: 13.823163064070103
# Total Timesteps: 2123 Episode Num: 144 Reward: 16.57695157691924
# Total Timesteps: 2131 Episode Num: 145 Reward: 11.139136140180925
# Total Timesteps: 2144 Episode Num: 146 Reward: 18.232049663948416
# Total Timesteps: 2177 Episode Num: 147 Reward: 25.273701195017203
# Total Timesteps: 2196 Episode Num: 148 Reward: 14.581369958195133
# Total Timesteps: 2221 Episode Num: 149 Reward: 20.349947615117706
# Total Timesteps: 2230 Episode Num: 150 Reward: 13.71066832877259
# Total Timesteps: 2238 Episode Num: 151 Reward: 12.677968060369311
# Total Timesteps: 2248 Episode Num: 152 Reward: 14.85536594418809
# Total Timesteps: 2258 Episode Num: 153 Reward: 13.817024371521256
# Total Timesteps: 2282 Episode Num: 154 Reward: 21.424634397188495
# Total Timesteps: 2293 Episode Num: 155 Reward: 14.224478044216813
# Total Timesteps: 2303 Episode Num: 156 Reward: 12.605650803155731
# Total Timesteps: 2314 Episode Num: 157 Reward: 15.54492486014642
# Total Timesteps: 2333 Episode Num: 158 Reward: 20.795544283741034
# Total Timesteps: 2348 Episode Num: 159 Reward: 16.865077729849144
# Total Timesteps: 2368 Episode Num: 160 Reward: 20.711370671499758
# Total Timesteps: 2398 Episode Num: 161 Reward: 26.1203375736397
# Total Timesteps: 2409 Episode Num: 162 Reward: 15.596485744109671
# Total Timesteps: 2418 Episode Num: 163 Reward: 13.222339173742512
# Total Timesteps: 2431 Episode Num: 164 Reward: 14.647846517337895
# Total Timesteps: 2446 Episode Num: 165 Reward: 18.01315112635202
# Total Timesteps: 2458 Episode Num: 166 Reward: 16.327369260697743
# Total Timesteps: 2477 Episode Num: 167 Reward: 20.239343688939698
# Total Timesteps: 2497 Episode Num: 168 Reward: 19.459486986257254
# Total Timesteps: 2522 Episode Num: 169 Reward: 25.043320454683275
# Total Timesteps: 2557 Episode Num: 170 Reward: 34.375677924974305
# Total Timesteps: 2567 Episode Num: 171 Reward: 12.08839261567773
# Total Timesteps: 2576 Episode Num: 172 Reward: 12.07975940858887
# Total Timesteps: 2586 Episode Num: 173 Reward: 14.721936758168157
# Total Timesteps: 2597 Episode Num: 174 Reward: 14.803332724007486
# Total Timesteps: 2615 Episode Num: 175 Reward: 17.035214704948885
# Total Timesteps: 2628 Episode Num: 176 Reward: 15.089022029796618
# Total Timesteps: 2638 Episode Num: 177 Reward: 14.883131666595
# Total Timesteps: 2653 Episode Num: 178 Reward: 15.695432887176867
# Total Timesteps: 2663 Episode Num: 179 Reward: 14.64768484927481
# Total Timesteps: 2686 Episode Num: 180 Reward: 23.22437312204129
# Total Timesteps: 2700 Episode Num: 181 Reward: 18.498010260263985
# Total Timesteps: 2712 Episode Num: 182 Reward: 16.513365665316815
# Total Timesteps: 2730 Episode Num: 183 Reward: 18.970557448161706
# Total Timesteps: 2740 Episode Num: 184 Reward: 14.069409208092837
# Total Timesteps: 2751 Episode Num: 185 Reward: 13.742177981708664
# Total Timesteps: 2764 Episode Num: 186 Reward: 15.904989285522607
# Total Timesteps: 2780 Episode Num: 187 Reward: 14.754366616639892
# Total Timesteps: 2796 Episode Num: 188 Reward: 17.650289806972435
# Total Timesteps: 2803 Episode Num: 189 Reward: 11.119510659540538
# Total Timesteps: 2820 Episode Num: 190 Reward: 19.256421498331477
# Total Timesteps: 2832 Episode Num: 191 Reward: 17.26028105535806
# Total Timesteps: 2858 Episode Num: 192 Reward: 21.52444321580115
# Total Timesteps: 2868 Episode Num: 193 Reward: 13.901787264434098
# Total Timesteps: 2885 Episode Num: 194 Reward: 19.248178258076948
# Total Timesteps: 2897 Episode Num: 195 Reward: 15.505458325173821
# Total Timesteps: 2911 Episode Num: 196 Reward: 17.375254164979555
# Total Timesteps: 2927 Episode Num: 197 Reward: 16.845490424837045
# Total Timesteps: 2942 Episode Num: 198 Reward: 15.598734859703105
# Total Timesteps: 2955 Episode Num: 199 Reward: 16.609017968426635
# Total Timesteps: 2976 Episode Num: 200 Reward: 22.759731666841255
# Total Timesteps: 2993 Episode Num: 201 Reward: 17.45655774326442
# Total Timesteps: 3008 Episode Num: 202 Reward: 20.09757919218973
# Total Timesteps: 3019 Episode Num: 203 Reward: 13.062514644184558
# Total Timesteps: 3034 Episode Num: 204 Reward: 16.272798520117068
# Total Timesteps: 3050 Episode Num: 205 Reward: 18.580042666029478
# Total Timesteps: 3058 Episode Num: 206 Reward: 12.604956139586283
# Total Timesteps: 3074 Episode Num: 207 Reward: 18.82387703861168
# Total Timesteps: 3081 Episode Num: 208 Reward: 11.671864792886481
# Total Timesteps: 3111 Episode Num: 209 Reward: 23.808078057500826
# Total Timesteps: 3123 Episode Num: 210 Reward: 16.65678102257225
# Total Timesteps: 3133 Episode Num: 211 Reward: 13.806514126194816
# Total Timesteps: 3157 Episode Num: 212 Reward: 21.921405087306628
# Total Timesteps: 3166 Episode Num: 213 Reward: 13.804350417396925
# Total Timesteps: 3185 Episode Num: 214 Reward: 17.896920734572635
# Total Timesteps: 3200 Episode Num: 215 Reward: 16.050693993132153
# Total Timesteps: 3211 Episode Num: 216 Reward: 15.688065661238214
# Total Timesteps: 3227 Episode Num: 217 Reward: 17.84209713076125
# Total Timesteps: 3237 Episode Num: 218 Reward: 14.415937874402152
# Total Timesteps: 3252 Episode Num: 219 Reward: 18.106226913564022
# Total Timesteps: 3262 Episode Num: 220 Reward: 14.761572439144947
# Total Timesteps: 3278 Episode Num: 221 Reward: 18.041320169599203
# Total Timesteps: 3292 Episode Num: 222 Reward: 16.281173755414784
# Total Timesteps: 3303 Episode Num: 223 Reward: 16.099726078771347
# Total Timesteps: 3311 Episode Num: 224 Reward: 13.531307266710792
# Total Timesteps: 3330 Episode Num: 225 Reward: 19.966142165946078
# Total Timesteps: 3340 Episode Num: 226 Reward: 13.442528895135908
# Total Timesteps: 3348 Episode Num: 227 Reward: 13.834290931248686
# Total Timesteps: 3365 Episode Num: 228 Reward: 18.845855449597
# Total Timesteps: 3381 Episode Num: 229 Reward: 17.083116721945405
# Total Timesteps: 3392 Episode Num: 230 Reward: 14.84745391887409
# Total Timesteps: 3403 Episode Num: 231 Reward: 13.933590602537151
# Total Timesteps: 3412 Episode Num: 232 Reward: 14.916969479488033
# Total Timesteps: 5335 Episode Num: 364 Reward: 13.288133245495555
# Total Timesteps: 5350 Episode Num: 365 Reward: 17.720010840476608
# Total Timesteps: 5367 Episode Num: 366 Reward: 19.206363024962776
# Total Timesteps: 5378 Episode Num: 367 Reward: 12.432569072514887
# Total Timesteps: 5388 Episode Num: 368 Reward: 14.226258979663545
# Total Timesteps: 5410 Episode Num: 369 Reward: 21.754963448359923
# Total Timesteps: 5421 Episode Num: 370 Reward: 14.053078743508378
# Total Timesteps: 5432 Episode Num: 371 Reward: 14.814416212713695
# Total Timesteps: 5445 Episode Num: 372 Reward: 17.23488427988341
# Total Timesteps: 5458 Episode Num: 373 Reward: 16.881299170007694
# Total Timesteps: 5467 Episode Num: 374 Reward: 13.375342848424044
# Total Timesteps: 5486 Episode Num: 375 Reward: 20.97729101056902
# Total Timesteps: 5500 Episode Num: 376 Reward: 18.708607212878995
# Total Timesteps: 5512 Episode Num: 377 Reward: 16.12723839554965
# Total Timesteps: 5520 Episode Num: 378 Reward: 13.827668414950312
# Total Timesteps: 5541 Episode Num: 379 Reward: 23.467224901811278
# Total Timesteps: 5559 Episode Num: 380 Reward: 17.83105612521322
# Total Timesteps: 5579 Episode Num: 381 Reward: 20.202389493375087
# Total Timesteps: 5589 Episode Num: 382 Reward: 14.72891149300267
# Total Timesteps: 5606 Episode Num: 383 Reward: 20.66509011343878
# Total Timesteps: 5619 Episode Num: 384 Reward: 17.32779448596557
# Total Timesteps: 5628 Episode Num: 385 Reward: 13.526084432097559
# Total Timesteps: 5642 Episode Num: 386 Reward: 17.858871729209206
# Total Timesteps: 5655 Episode Num: 387 Reward: 15.763334422382467
# Total Timesteps: 5663 Episode Num: 388 Reward: 13.392243968813272
# Total Timesteps: 5688 Episode Num: 389 Reward: 22.42195686205959
# Total Timesteps: 5702 Episode Num: 390 Reward: 16.674515130413056
# Total Timesteps: 5721 Episode Num: 391 Reward: 19.872746831033144
# Total Timesteps: 5739 Episode Num: 392 Reward: 19.882944950106324
# Total Timesteps: 5765 Episode Num: 393 Reward: 22.999607417575316
# Total Timesteps: 5776 Episode Num: 394 Reward: 13.100143397200736
# Total Timesteps: 5796 Episode Num: 395 Reward: 19.862617459813187
# Total Timesteps: 5806 Episode Num: 396 Reward: 13.687041953150766
# Total Timesteps: 5827 Episode Num: 397 Reward: 23.29342837876029
# Total Timesteps: 5837 Episode Num: 398 Reward: 15.540910700864334
# Total Timesteps: 5847 Episode Num: 399 Reward: 13.957298946383526
# Total Timesteps: 5859 Episode Num: 400 Reward: 14.511367612164758
# Total Timesteps: 5869 Episode Num: 401 Reward: 13.424206342728576
# Total Timesteps: 5883 Episode Num: 402 Reward: 18.191513984918128
# Total Timesteps: 5899 Episode Num: 403 Reward: 19.320280866825488
# Total Timesteps: 5906 Episode Num: 404 Reward: 11.999719212591298
# Total Timesteps: 5917 Episode Num: 405 Reward: 15.899271948634123
# Total Timesteps: 5937 Episode Num: 406 Reward: 19.11554742583248
# Total Timesteps: 5947 Episode Num: 407 Reward: 14.083014646892844
# Total Timesteps: 5962 Episode Num: 408 Reward: 15.090456827054728
# Total Timesteps: 5976 Episode Num: 409 Reward: 16.547448577967593
# Total Timesteps: 5993 Episode Num: 410 Reward: 17.17768136591621
# Total Timesteps: 6007 Episode Num: 411 Reward: 17.76994587191293
# Total Timesteps: 6016 Episode Num: 412 Reward: 12.52588117162086
# Total Timesteps: 6028 Episode Num: 413 Reward: 15.821100618963825
# Total Timesteps: 6047 Episode Num: 414 Reward: 19.00669357205916
# Total Timesteps: 6056 Episode Num: 415 Reward: 11.608530897603487
# Total Timesteps: 6076 Episode Num: 416 Reward: 20.009184531621578
# Total Timesteps: 6105 Episode Num: 417 Reward: 28.340438476338743
# Total Timesteps: 6118 Episode Num: 418 Reward: 14.491928669085612
# Total Timesteps: 6128 Episode Num: 419 Reward: 14.486070374315023
# Total Timesteps: 6139 Episode Num: 420 Reward: 15.259006048322773
# Total Timesteps: 6160 Episode Num: 421 Reward: 20.11590663408715
# Total Timesteps: 6175 Episode Num: 422 Reward: 16.920023104960272
# Total Timesteps: 6188 Episode Num: 423 Reward: 14.478284045311739
# Total Timesteps: 6201 Episode Num: 424 Reward: 17.087862970124114
# Total Timesteps: 6223 Episode Num: 425 Reward: 21.1810921028853
# Total Timesteps: 6247 Episode Num: 426 Reward: 22.82065100695181
# Total Timesteps: 6255 Episode Num: 427 Reward: 13.689256260002729
# Total Timesteps: 6266 Episode Num: 428 Reward: 15.198621668796113
# Total Timesteps: 6280 Episode Num: 429 Reward: 16.761865832319014
# Total Timesteps: 6306 Episode Num: 430 Reward: 20.01045403765747
# Total Timesteps: 6322 Episode Num: 431 Reward: 18.863343966305546
# Total Timesteps: 6332 Episode Num: 432 Reward: 12.744642652360199
# Total Timesteps: 6339 Episode Num: 433 Reward: 12.855302435890188
# Total Timesteps: 6346 Episode Num: 434 Reward: 11.691593132767593
# Total Timesteps: 6355 Episode Num: 435 Reward: 14.547756823264352
# Total Timesteps: 6364 Episode Num: 436 Reward: 13.861549659071896
# Total Timesteps: 6379 Episode Num: 437 Reward: 14.748117487669514
# Total Timesteps: 6386 Episode Num: 438 Reward: 12.169645050435793
# Total Timesteps: 6404 Episode Num: 439 Reward: 21.643573045458467
# Total Timesteps: 6415 Episode Num: 440 Reward: 14.25427011661377
# Total Timesteps: 6425 Episode Num: 441 Reward: 15.025005341832003
# Total Timesteps: 6436 Episode Num: 442 Reward: 12.846932438074145
# Total Timesteps: 6448 Episode Num: 443 Reward: 17.053873703931462
# Total Timesteps: 6472 Episode Num: 444 Reward: 22.88622466957895
# Total Timesteps: 6483 Episode Num: 445 Reward: 13.92820221279835
# Total Timesteps: 6493 Episode Num: 446 Reward: 14.563984276934933
# Total Timesteps: 6503 Episode Num: 447 Reward: 15.620142163574927
# Total Timesteps: 6513 Episode Num: 448 Reward: 15.7984221132152
# Total Timesteps: 6527 Episode Num: 449 Reward: 15.845583263575099
# Total Timesteps: 6551 Episode Num: 450 Reward: 24.615552322025177
# Total Timesteps: 6566 Episode Num: 451 Reward: 16.298346448235684
# Total Timesteps: 6585 Episode Num: 452 Reward: 17.463642213799183
# Total Timesteps: 7886 Episode Num: 542 Reward: 15.650298923422813
# Total Timesteps: 7894 Episode Num: 543 Reward: 12.221029601641929
# Total Timesteps: 7912 Episode Num: 544 Reward: 18.506077317245946
# Total Timesteps: 7925 Episode Num: 545 Reward: 17.89465309328516
# Total Timesteps: 7935 Episode Num: 546 Reward: 15.56836267923645
# Total Timesteps: 7949 Episode Num: 547 Reward: 15.468153930499104
# Total Timesteps: 7974 Episode Num: 548 Reward: 25.13097150625981
# Total Timesteps: 7981 Episode Num: 549 Reward: 11.877090019917523
# Total Timesteps: 7992 Episode Num: 550 Reward: 14.215323575463843
# Total Timesteps: 8002 Episode Num: 551 Reward: 14.90570753557695
# Total Timesteps: 8012 Episode Num: 552 Reward: 13.178887362174283
# Total Timesteps: 8043 Episode Num: 553 Reward: 28.448919534026924
# Total Timesteps: 8057 Episode Num: 554 Reward: 17.275356423655463
# Total Timesteps: 8075 Episode Num: 555 Reward: 19.665304788395588
# Total Timesteps: 8094 Episode Num: 556 Reward: 19.130090496655612
# Total Timesteps: 8106 Episode Num: 557 Reward: 16.459327131412284
# Total Timesteps: 8116 Episode Num: 558 Reward: 14.488092584379775
# Total Timesteps: 8128 Episode Num: 559 Reward: 13.006760426414257
# Total Timesteps: 8141 Episode Num: 560 Reward: 15.542052967401101
# Total Timesteps: 8150 Episode Num: 561 Reward: 14.400871285769972
# Total Timesteps: 8160 Episode Num: 562 Reward: 15.010507124528521
# Total Timesteps: 8171 Episode Num: 563 Reward: 15.982472593073908
# Total Timesteps: 8183 Episode Num: 564 Reward: 15.684951603018272
# Total Timesteps: 8191 Episode Num: 565 Reward: 12.388899774139281
# Total Timesteps: 8207 Episode Num: 566 Reward: 15.432115548687579
# Total Timesteps: 8226 Episode Num: 567 Reward: 20.495807990283353
# Total Timesteps: 8239 Episode Num: 568 Reward: 16.77002633540833
# Total Timesteps: 8254 Episode Num: 569 Reward: 17.684542789674015
# Total Timesteps: 8275 Episode Num: 570 Reward: 22.40668258290388
# Total Timesteps: 8281 Episode Num: 571 Reward: 10.807066443211806
# Total Timesteps: 8290 Episode Num: 572 Reward: 13.24888088776788
# Total Timesteps: 8299 Episode Num: 573 Reward: 13.817233190554543
# Total Timesteps: 8311 Episode Num: 574 Reward: 15.750317851449653
# Total Timesteps: 8322 Episode Num: 575 Reward: 14.22183374943852
# Total Timesteps: 8351 Episode Num: 576 Reward: 27.785013484870422
# Total Timesteps: 8365 Episode Num: 577 Reward: 17.745998299830536
# Total Timesteps: 8382 Episode Num: 578 Reward: 16.11464859875559
# Total Timesteps: 8401 Episode Num: 579 Reward: 20.635640933946707
# Total Timesteps: 8409 Episode Num: 580 Reward: 10.710843131520958
# Total Timesteps: 8421 Episode Num: 581 Reward: 16.003607602135162
# Total Timesteps: 8433 Episode Num: 582 Reward: 13.434396259860659
# Total Timesteps: 8443 Episode Num: 583 Reward: 14.048749772988959
# Total Timesteps: 8451 Episode Num: 584 Reward: 13.312539256380113
# Total Timesteps: 8471 Episode Num: 585 Reward: 21.97186909943557
# Total Timesteps: 8480 Episode Num: 586 Reward: 13.224124636764463
# Total Timesteps: 8495 Episode Num: 587 Reward: 15.19370088311407
# Total Timesteps: 8504 Episode Num: 588 Reward: 14.619512995996045
# Total Timesteps: 8521 Episode Num: 589 Reward: 19.188301223165766
# Total Timesteps: 8541 Episode Num: 590 Reward: 20.979499695394768
# Total Timesteps: 8550 Episode Num: 591 Reward: 15.830312095025146
# Total Timesteps: 8566 Episode Num: 592 Reward: 15.590998994521218
# Total Timesteps: 8577 Episode Num: 593 Reward: 14.286456646872102
# Total Timesteps: 8586 Episode Num: 594 Reward: 13.28759233563469
# Total Timesteps: 8595 Episode Num: 595 Reward: 13.980227264622227
# Total Timesteps: 8612 Episode Num: 596 Reward: 19.46469703305775
# Total Timesteps: 8627 Episode Num: 597 Reward: 18.627642202760033
# Total Timesteps: 8638 Episode Num: 598 Reward: 13.890509045041108
# Total Timesteps: 8655 Episode Num: 599 Reward: 18.047334620769835
# Total Timesteps: 8662 Episode Num: 600 Reward: 11.160190761731064
# Total Timesteps: 8677 Episode Num: 601 Reward: 18.484640529796888
# Total Timesteps: 8687 Episode Num: 602 Reward: 13.07194399346481
# Total Timesteps: 8695 Episode Num: 603 Reward: 12.820103695688884
# Total Timesteps: 8707 Episode Num: 604 Reward: 15.884855282490024
# Total Timesteps: 8718 Episode Num: 605 Reward: 13.03687255084078
# Total Timesteps: 8736 Episode Num: 606 Reward: 17.74446502998326
# Total Timesteps: 8748 Episode Num: 607 Reward: 17.533408597277592
# Total Timesteps: 8761 Episode Num: 608 Reward: 17.0723897130767
# Total Timesteps: 8768 Episode Num: 609 Reward: 12.33488843737723
# Total Timesteps: 8783 Episode Num: 610 Reward: 18.18325387434743
# Total Timesteps: 8789 Episode Num: 611 Reward: 11.502765599390841
# Total Timesteps: 8801 Episode Num: 612 Reward: 16.39292748479202
# Total Timesteps: 8814 Episode Num: 613 Reward: 16.60332695047837
# Total Timesteps: 8824 Episode Num: 614 Reward: 13.321126510860632
# Total Timesteps: 8837 Episode Num: 615 Reward: 16.298629566548332
# Total Timesteps: 8849 Episode Num: 616 Reward: 16.326172418144417
# Total Timesteps: 8865 Episode Num: 617 Reward: 20.73785872774606
# Total Timesteps: 8879 Episode Num: 618 Reward: 17.17397787636146
# Total Timesteps: 8892 Episode Num: 619 Reward: 17.50388238325977
# Total Timesteps: 8906 Episode Num: 620 Reward: 18.038441415868874
# Total Timesteps: 8923 Episode Num: 621 Reward: 18.786013912907222
# Total Timesteps: 8931 Episode Num: 622 Reward: 11.94659662627382
# Total Timesteps: 8958 Episode Num: 623 Reward: 24.098933597560976
# Total Timesteps: 8973 Episode Num: 624 Reward: 16.63794909402204
# Total Timesteps: 8985 Episode Num: 625 Reward: 15.96662564622093
# Total Timesteps: 8998 Episode Num: 626 Reward: 16.95516097390937
# Total Timesteps: 9008 Episode Num: 627 Reward: 13.975153020005383
# Total Timesteps: 9019 Episode Num: 628 Reward: 14.258278564260399
# Total Timesteps: 9029 Episode Num: 629 Reward: 15.920206151432652
# Total Timesteps: 9040 Episode Num: 630 Reward: 13.663022619824917
# Total Timesteps: 9055 Episode Num: 631 Reward: 19.44479241896333
# Total Timesteps: 9067 Episode Num: 632 Reward: 15.55284234980354
# Total Timesteps: 9082 Episode Num: 633 Reward: 13.984473332797641
# Total Timesteps: 9100 Episode Num: 634 Reward: 17.557545022321577
# Total Timesteps: 9114 Episode Num: 635 Reward: 15.649353390636678
# Total Timesteps: 9126 Episode Num: 636 Reward: 17.40708700606483
# Total Timesteps: 9136 Episode Num: 637 Reward: 16.005030495392568
# Total Timesteps: 9144 Episode Num: 638 Reward: 12.344514090786106
# Total Timesteps: 9159 Episode Num: 639 Reward: 16.314168553506896
# Total Timesteps: 9169 Episode Num: 640 Reward: 13.737907757720675
# Total Timesteps: 9178 Episode Num: 641 Reward: 14.28607154770434
# Total Timesteps: 9202 Episode Num: 642 Reward: 21.827286448753146
# Total Timesteps: 9219 Episode Num: 643 Reward: 20.557661183222077
# Total Timesteps: 9227 Episode Num: 644 Reward: 12.109304306190461
# Total Timesteps: 9249 Episode Num: 645 Reward: 20.256988180863846
# Total Timesteps: 9265 Episode Num: 646 Reward: 21.12995159707789
# Total Timesteps: 9274 Episode Num: 647 Reward: 12.66234574659902
# Total Timesteps: 9286 Episode Num: 648 Reward: 16.078417972470923
# Total Timesteps: 9308 Episode Num: 649 Reward: 20.16118409480114
# Total Timesteps: 9318 Episode Num: 650 Reward: 12.98016273224348
# Total Timesteps: 9324 Episode Num: 651 Reward: 10.724008488238905
# Total Timesteps: 9339 Episode Num: 652 Reward: 18.492989824063258
# Total Timesteps: 9363 Episode Num: 653 Reward: 25.574314054338902
# Total Timesteps: 9375 Episode Num: 654 Reward: 15.481019505059521
# Total Timesteps: 9393 Episode Num: 655 Reward: 19.672761701671696
# Total Timesteps: 9411 Episode Num: 656 Reward: 19.35068768882484
# Total Timesteps: 9427 Episode Num: 657 Reward: 19.79031855801877
# Total Timesteps: 9438 Episode Num: 658 Reward: 12.72846878008131
# Total Timesteps: 9458 Episode Num: 659 Reward: 22.363743927463656
# Total Timesteps: 9473 Episode Num: 660 Reward: 16.972525710288025
# Total Timesteps: 9489 Episode Num: 661 Reward: 15.69541924094665
# Total Timesteps: 9497 Episode Num: 662 Reward: 12.158644385471415
# Total Timesteps: 9507 Episode Num: 663 Reward: 14.446813063127049
# Total Timesteps: 9522 Episode Num: 664 Reward: 16.30650125929824
# Total Timesteps: 9533 Episode Num: 665 Reward: 15.610658557499118
# Total Timesteps: 9562 Episode Num: 666 Reward: 30.310725314948648
# Total Timesteps: 9584 Episode Num: 667 Reward: 22.64344685433753
# Total Timesteps: 9598 Episode Num: 668 Reward: 16.430111936778122
# Total Timesteps: 9612 Episode Num: 669 Reward: 15.715133433043956
# Total Timesteps: 9622 Episode Num: 670 Reward: 14.840606508412748
# Total Timesteps: 9631 Episode Num: 671 Reward: 13.358628766804758
# Total Timesteps: 9642 Episode Num: 672 Reward: 15.40482267000625
# Total Timesteps: 9655 Episode Num: 673 Reward: 17.41075648914266
# Total Timesteps: 9675 Episode Num: 674 Reward: 20.177312879213424
# Total Timesteps: 9692 Episode Num: 675 Reward: 18.28802054917178
# Total Timesteps: 9699 Episode Num: 676 Reward: 11.697322167518724
# Total Timesteps: 9716 Episode Num: 677 Reward: 19.433671642745317
# Total Timesteps: 9731 Episode Num: 678 Reward: 17.253415919223333
# Total Timesteps: 9747 Episode Num: 679 Reward: 19.243765385018193
# Total Timesteps: 9767 Episode Num: 680 Reward: 17.463684477210332
# Total Timesteps: 9779 Episode Num: 681 Reward: 17.392265438141475
# Total Timesteps: 9796 Episode Num: 682 Reward: 19.585771202933387
# Total Timesteps: 9806 Episode Num: 683 Reward: 14.533377866688532
# Total Timesteps: 9815 Episode Num: 684 Reward: 15.2244596037257
# Total Timesteps: 9829 Episode Num: 685 Reward: 17.335131946874025
# Total Timesteps: 9846 Episode Num: 686 Reward: 19.08973255768069
# Total Timesteps: 9855 Episode Num: 687 Reward: 13.937447609679657
# Total Timesteps: 9873 Episode Num: 688 Reward: 19.683599435455108
# Total Timesteps: 9885 Episode Num: 689 Reward: 17.474232763127656
# Total Timesteps: 9893 Episode Num: 690 Reward: 12.622662835955268
# Total Timesteps: 9908 Episode Num: 691 Reward: 17.86434396331024
# Total Timesteps: 9920 Episode Num: 692 Reward: 16.120487300572858
# Total Timesteps: 9943 Episode Num: 693 Reward: 25.015482973596956
# Total Timesteps: 9957 Episode Num: 694 Reward: 16.58411033366865
# Total Timesteps: 9967 Episode Num: 695 Reward: 14.399817266216267
# Total Timesteps: 9981 Episode Num: 696 Reward: 14.590547388281266
# Total Timesteps: 9999 Episode Num: 697 Reward: 21.484138622898897
# Total Timesteps: 10122 Episode Num: 698 Reward: 82.04585840623675
# ---------------------------------------
# Average Reward over the Evaluation Step: 22.368108
# ---------------------------------------
# Total Timesteps: 10170 Episode Num: 699 Reward: 47.61875294868024
# Total Timesteps: 10235 Episode Num: 700 Reward: 5.714812558326171
# Total Timesteps: 10297 Episode Num: 701 Reward: 68.04340717273806
# Total Timesteps: 10412 Episode Num: 702 Reward: 93.57849847321398
# Total Timesteps: 10483 Episode Num: 703 Reward: 86.24975112196641
# Total Timesteps: 10534 Episode Num: 704 Reward: 59.87718347498618
# Total Timesteps: 10599 Episode Num: 705 Reward: 77.8610229556009
# Total Timesteps: 10652 Episode Num: 706 Reward: 59.55707354193017
# Total Timesteps: 10721 Episode Num: 707 Reward: 72.62822545133366
# Total Timesteps: 10788 Episode Num: 708 Reward: 77.19001239187173
# Total Timesteps: 10857 Episode Num: 709 Reward: 82.98196546092389
# Total Timesteps: 10925 Episode Num: 710 Reward: 75.83193372442442
# Total Timesteps: 10993 Episode Num: 711 Reward: 78.97467708990096
# Total Timesteps: 11039 Episode Num: 712 Reward: 29.76818576436793
# Total Timesteps: 11151 Episode Num: 713 Reward: 115.27277236121176
# Total Timesteps: 11193 Episode Num: 714 Reward: 37.47757829420052
# Total Timesteps: 11242 Episode Num: 715 Reward: 27.972320180475386
# Total Timesteps: 11292 Episode Num: 716 Reward: 46.44286680667033
# Total Timesteps: 11345 Episode Num: 717 Reward: 70.91044488449715
# Total Timesteps: 11405 Episode Num: 718 Reward: 72.96341070091341
# Total Timesteps: 11465 Episode Num: 719 Reward: 76.50864412425865
# Total Timesteps: 11490 Episode Num: 720 Reward: 22.706244753065224
# Total Timesteps: 11524 Episode Num: 721 Reward: 33.30490406479695
# Total Timesteps: 11562 Episode Num: 722 Reward: 27.571772765115146
# Total Timesteps: 11593 Episode Num: 723 Reward: 23.30881254108781
# Total Timesteps: 11657 Episode Num: 724 Reward: 62.176135221275345
# Total Timesteps: 11693 Episode Num: 725 Reward: 41.49084372991623
# Total Timesteps: 11731 Episode Num: 726 Reward: 38.18629446470078
# Total Timesteps: 11846 Episode Num: 727 Reward: 107.15931426086007
# Total Timesteps: 11881 Episode Num: 728 Reward: 34.93380540172175
# Total Timesteps: 12039 Episode Num: 729 Reward: 150.91832215081578
# ...
# ---------------------------------------
# Average Reward over the Evaluation Step: 1543.747804
# ---------------------------------------
# Total Timesteps: 355957 Episode Num: 1610 Reward: 98.57078630895292
# Total Timesteps: 356957 Episode Num: 1611 Reward: 1502.0270203679966
# Total Timesteps: 357957 Episode Num: 1612 Reward: 1519.0171574773913
# Total Timesteps: 358957 Episode Num: 1613 Reward: 1593.510625485819
# Total Timesteps: 359957 Episode Num: 1614 Reward: 1660.5006106473559
# Total Timesteps: 360957 Episode Num: 1615 Reward: 1650.6667506106917
# ---------------------------------------
# Average Reward over the Evaluation Step: 1747.677630
# ---------------------------------------
# Total Timesteps: 361957 Episode Num: 1616 Reward: 1733.414233120226
# Total Timesteps: 362957 Episode Num: 1617 Reward: 1604.684320651115
# Total Timesteps: 363957 Episode Num: 1618 Reward: 1585.3094943469168
# Total Timesteps: 364957 Episode Num: 1619 Reward: 1607.4436451257727
# Total Timesteps: 365043 Episode Num: 1620 Reward: 114.54912541145153
# ---------------------------------------
# Average Reward over the Evaluation Step: 283.920869
# ---------------------------------------
# Total Timesteps: 365133 Episode Num: 1621 Reward: 110.6931467359319
# Total Timesteps: 365221 Episode Num: 1622 Reward: 118.78512693486316
# Total Timesteps: 365384 Episode Num: 1623 Reward: 248.7971900994025
# Total Timesteps: 365517 Episode Num: 1624 Reward: 206.23117254664686
# Total Timesteps: 365737 Episode Num: 1625 Reward: 326.91918835065746
# Total Timesteps: 366166 Episode Num: 1626 Reward: 632.6018422989522
# Total Timesteps: 366954 Episode Num: 1627 Reward: 1266.4290629926097
# Total Timesteps: 367954 Episode Num: 1628 Reward: 1557.9806255382193
# Total Timesteps: 368954 Episode Num: 1629 Reward: 1584.9430583138646
# Total Timesteps: 369954 Episode Num: 1630 Reward: 1521.4142770651993
# Total Timesteps: 370954 Episode Num: 1631 Reward: 1522.864915817818
# ---------------------------------------
# Average Reward over the Evaluation Step: 1606.910940
# ---------------------------------------
# Total Timesteps: 371954 Episode Num: 1632 Reward: 1567.1160864161009
# Total Timesteps: 372954 Episode Num: 1633 Reward: 1478.923116604541
# Total Timesteps: 373954 Episode Num: 1634 Reward: 1461.5899133020325
# Total Timesteps: 374954 Episode Num: 1635 Reward: 1425.292744097027
# Total Timesteps: 375954 Episode Num: 1636 Reward: 1379.490808366197
# ---------------------------------------
# Average Reward over the Evaluation Step: 330.349195
# ---------------------------------------
# Total Timesteps: 376117 Episode Num: 1637 Reward: 215.16937260397503
# Total Timesteps: 377117 Episode Num: 1638 Reward: 1484.5762102274036
# Total Timesteps: 377239 Episode Num: 1639 Reward: 169.51007774668145
# Total Timesteps: 377350 Episode Num: 1640 Reward: 142.05057849118512
# Total Timesteps: 377378 Episode Num: 1641 Reward: 26.807310685712487
# Total Timesteps: 377409 Episode Num: 1642 Reward: 26.8088718136342
# Total Timesteps: 377446 Episode Num: 1643 Reward: 26.240306050657914
# Total Timesteps: 377476 Episode Num: 1644 Reward: 32.81454425206949
# Total Timesteps: 377530 Episode Num: 1645 Reward: 36.73957919189936
# Total Timesteps: 377558 Episode Num: 1646 Reward: 28.132986504980238
# Total Timesteps: 378558 Episode Num: 1647 Reward: 1434.7392481597376
# Total Timesteps: 379558 Episode Num: 1648 Reward: 1464.7668080654219
# Total Timesteps: 380558 Episode Num: 1649 Reward: 1513.9876536290083
# ---------------------------------------
# Average Reward over the Evaluation Step: 1392.509339
# ---------------------------------------
# Total Timesteps: 381558 Episode Num: 1650 Reward: 1478.9847784033445
# Total Timesteps: 382558 Episode Num: 1651 Reward: 1574.3963915502925
# Total Timesteps: 382649 Episode Num: 1652 Reward: 44.84878085608661
# Total Timesteps: 383649 Episode Num: 1653 Reward: 1525.0057186788567
# Total Timesteps: 383746 Episode Num: 1654 Reward: 141.51231325220232
# Total Timesteps: 383818 Episode Num: 1655 Reward: 80.49718840025606
# Total Timesteps: 384012 Episode Num: 1656 Reward: 277.34136692499123
# Total Timesteps: 384389 Episode Num: 1657 Reward: 530.0393631302398
# Total Timesteps: 385389 Episode Num: 1658 Reward: 1443.4097754599056
# ---------------------------------------
# Average Reward over the Evaluation Step: 1206.835928
# ---------------------------------------
# Total Timesteps: 386389 Episode Num: 1659 Reward: 1363.9003070732417
# Total Timesteps: 387389 Episode Num: 1660 Reward: 1473.4565237656093
# Total Timesteps: 388389 Episode Num: 1661 Reward: 1348.0144555521379
# Total Timesteps: 389389 Episode Num: 1662 Reward: 1442.0200118330067
# Total Timesteps: 390389 Episode Num: 1663 Reward: 1486.0480782992377
# ---------------------------------------
# Average Reward over the Evaluation Step: 343.810424
# ---------------------------------------
# Total Timesteps: 390473 Episode Num: 1664 Reward: 98.06731529770953
# Total Timesteps: 391473 Episode Num: 1665 Reward: 1478.129678429976
# Total Timesteps: 392473 Episode Num: 1666 Reward: 1347.6527027000711
# Total Timesteps: 393473 Episode Num: 1667 Reward: 1469.9058478298941
# Total Timesteps: 394473 Episode Num: 1668 Reward: 1449.0909389175506
# Total Timesteps: 394569 Episode Num: 1669 Reward: 128.6186880708469
# Total Timesteps: 394778 Episode Num: 1670 Reward: 270.2531806452874
# Total Timesteps: 395778 Episode Num: 1671 Reward: 1464.465079497218
# ---------------------------------------
# Average Reward over the Evaluation Step: 1433.305087
# ---------------------------------------
# Total Timesteps: 396118 Episode Num: 1672 Reward: 498.2850683662404
# Total Timesteps: 396428 Episode Num: 1673 Reward: 443.6935522260581
# Total Timesteps: 396810 Episode Num: 1674 Reward: 536.8470670204082
# Total Timesteps: 397810 Episode Num: 1675 Reward: 1267.2192186813006
# Total Timesteps: 398810 Episode Num: 1676 Reward: 1351.7292709550222
# Total Timesteps: 399810 Episode Num: 1677 Reward: 1130.761242483304
# Total Timesteps: 399947 Episode Num: 1678 Reward: 150.7371773912016
# Total Timesteps: 400947 Episode Num: 1679 Reward: 1264.9440977225365
# ---------------------------------------
# Average Reward over the Evaluation Step: 1156.476399
# ---------------------------------------
# Total Timesteps: 401947 Episode Num: 1680 Reward: 1151.3972225191865
# Total Timesteps: 402947 Episode Num: 1681 Reward: 1194.360600798641
# Total Timesteps: 403947 Episode Num: 1682 Reward: 1360.5429113023745
# Total Timesteps: 404947 Episode Num: 1683 Reward: 1339.8042687691711
# Total Timesteps: 405947 Episode Num: 1684 Reward: 1557.4510095963747
# ---------------------------------------
# Average Reward over the Evaluation Step: 1541.664369
# ---------------------------------------
# Total Timesteps: 406947 Episode Num: 1685 Reward: 1540.9774733577387
# Total Timesteps: 407947 Episode Num: 1686 Reward: 1535.7816166604832
# Total Timesteps: 408947 Episode Num: 1687 Reward: 1658.7906532760037
# Total Timesteps: 409188 Episode Num: 1688 Reward: 388.98391567052767
# Total Timesteps: 409527 Episode Num: 1689 Reward: 488.5862864323876
# Total Timesteps: 410527 Episode Num: 1690 Reward: 1509.1759058204075
# ---------------------------------------
# Average Reward over the Evaluation Step: 1591.513425
# ---------------------------------------
# Total Timesteps: 411527 Episode Num: 1691 Reward: 1560.9010208179704
# Total Timesteps: 412427 Episode Num: 1692 Reward: 1423.264480571156
# Total Timesteps: 412546 Episode Num: 1693 Reward: 163.4927421329977
# Total Timesteps: 413546 Episode Num: 1694 Reward: 1605.2238730699946
# Total Timesteps: 413708 Episode Num: 1695 Reward: 257.66549468813247
# Total Timesteps: 414708 Episode Num: 1696 Reward: 1725.345541427303
# Total Timesteps: 415708 Episode Num: 1697 Reward: 1495.0421569244002
# ---------------------------------------
# Average Reward over the Evaluation Step: 1522.463159
# ---------------------------------------
# Total Timesteps: 416708 Episode Num: 1698 Reward: 1572.4387054302906
# Total Timesteps: 417351 Episode Num: 1699 Reward: 1084.126382481063
# Total Timesteps: 418351 Episode Num: 1700 Reward: 1591.3755596487747
# Total Timesteps: 418561 Episode Num: 1701 Reward: 309.4228818873306
# Total Timesteps: 419227 Episode Num: 1702 Reward: 1002.1556511529013
# Total Timesteps: 420227 Episode Num: 1703 Reward: 1501.9977677740126
# ---------------------------------------
# Average Reward over the Evaluation Step: 1387.700198
# ---------------------------------------
# Total Timesteps: 421198 Episode Num: 1704 Reward: 1325.1222951560692
# Total Timesteps: 422198 Episode Num: 1705 Reward: 1616.0333921358128
# Total Timesteps: 423198 Episode Num: 1706 Reward: 1690.8995218103432
# Total Timesteps: 424198 Episode Num: 1707 Reward: 1550.7672616232055
# Total Timesteps: 425198 Episode Num: 1708 Reward: 1608.0957059574325
# ---------------------------------------
# Average Reward over the Evaluation Step: 1750.634852
# ---------------------------------------
# Total Timesteps: 426198 Episode Num: 1709 Reward: 1739.8563692867367
# Total Timesteps: 427198 Episode Num: 1710 Reward: 1741.313628204715
# Total Timesteps: 428198 Episode Num: 1711 Reward: 1606.5343415293182
# Total Timesteps: 429198 Episode Num: 1712 Reward: 1671.5314363239108
# Total Timesteps: 430198 Episode Num: 1713 Reward: 1810.0402838780317
# ---------------------------------------
# Average Reward over the Evaluation Step: 1558.674614
# ---------------------------------------
# Total Timesteps: 431198 Episode Num: 1714 Reward: 1498.6010983821184
# Total Timesteps: 432198 Episode Num: 1715 Reward: 1593.366986366844
# Total Timesteps: 433198 Episode Num: 1716 Reward: 1700.1450279034336
# Total Timesteps: 434198 Episode Num: 1717 Reward: 1685.3274796521937
# Total Timesteps: 435198 Episode Num: 1718 Reward: 1656.0821220960786
# ---------------------------------------
# Average Reward over the Evaluation Step: 881.314535
# ---------------------------------------
# Total Timesteps: 436141 Episode Num: 1719 Reward: 1623.561113743119
# Total Timesteps: 437141 Episode Num: 1720 Reward: 1717.1002896883856
# Total Timesteps: 438141 Episode Num: 1721 Reward: 1745.281650288363
# Total Timesteps: 439141 Episode Num: 1722 Reward: 1596.6259743764417
# Total Timesteps: 440141 Episode Num: 1723 Reward: 1690.722932494343
# ---------------------------------------
# Average Reward over the Evaluation Step: 1705.876914
# ---------------------------------------
# Total Timesteps: 441141 Episode Num: 1724 Reward: 1707.0383078853154
# Total Timesteps: 442141 Episode Num: 1725 Reward: 1597.4187865651832
# Total Timesteps: 443141 Episode Num: 1726 Reward: 1523.2572566215915
# Total Timesteps: 444141 Episode Num: 1727 Reward: 1587.3124836477546
# Total Timesteps: 445141 Episode Num: 1728 Reward: 1821.2321580054834
# ---------------------------------------
# Average Reward over the Evaluation Step: 1436.494051
# ---------------------------------------
# Total Timesteps: 446141 Episode Num: 1729 Reward: 1439.17545953169
# Total Timesteps: 447141 Episode Num: 1730 Reward: 1560.3876242463318
# Total Timesteps: 448141 Episode Num: 1731 Reward: 1542.7686959624593
# Total Timesteps: 449141 Episode Num: 1732 Reward: 1466.56760781618
# Total Timesteps: 450141 Episode Num: 1733 Reward: 1390.9790765278776
# ---------------------------------------
# Average Reward over the Evaluation Step: 1243.171205
# ---------------------------------------
# Total Timesteps: 450581 Episode Num: 1734 Reward: 668.9759259432215
# Total Timesteps: 451581 Episode Num: 1735 Reward: 1702.9754187331625
# Total Timesteps: 452581 Episode Num: 1736 Reward: 1639.7281515259249
# Total Timesteps: 453581 Episode Num: 1737 Reward: 1683.5286324899864
# Total Timesteps: 454581 Episode Num: 1738 Reward: 1699.226021957037
# Total Timesteps: 455581 Episode Num: 1739 Reward: 1765.9893749290104
# ---------------------------------------
# Average Reward over the Evaluation Step: 1691.047981
# ---------------------------------------
# Total Timesteps: 456581 Episode Num: 1740 Reward: 1702.8054463786043
# Total Timesteps: 457581 Episode Num: 1741 Reward: 1598.0247235631873
# Total Timesteps: 458581 Episode Num: 1742 Reward: 1617.794949016034
# Total Timesteps: 459581 Episode Num: 1743 Reward: 1579.1001039703697
# Total Timesteps: 460581 Episode Num: 1744 Reward: 1614.8924047702642
# ---------------------------------------
# Average Reward over the Evaluation Step: 1579.815771
# ---------------------------------------
# Total Timesteps: 461581 Episode Num: 1745 Reward: 1589.4762102322973
# Total Timesteps: 462581 Episode Num: 1746 Reward: 1536.3256450269866
# Total Timesteps: 463581 Episode Num: 1747 Reward: 1607.9336113479092
# Total Timesteps: 464581 Episode Num: 1748 Reward: 1631.4482637850158
# Total Timesteps: 465581 Episode Num: 1749 Reward: 1562.9897853105228
# ---------------------------------------
# Average Reward over the Evaluation Step: 1704.892164
# ---------------------------------------
# Total Timesteps: 466581 Episode Num: 1750 Reward: 1649.4244834628403
# Total Timesteps: 467581 Episode Num: 1751 Reward: 1511.4525884709851
# Total Timesteps: 468581 Episode Num: 1752 Reward: 1706.4273735467837
# Total Timesteps: 469581 Episode Num: 1753 Reward: 1708.5533399326403
# Total Timesteps: 470581 Episode Num: 1754 Reward: 1808.925465395306
# ---------------------------------------
# Average Reward over the Evaluation Step: 1759.165266
# ---------------------------------------
# Total Timesteps: 471581 Episode Num: 1755 Reward: 1769.3554299825919
# Total Timesteps: 472581 Episode Num: 1756 Reward: 1771.157412866045
# Total Timesteps: 473581 Episode Num: 1757 Reward: 1768.9927785282732
# Total Timesteps: 474581 Episode Num: 1758 Reward: 1710.140258580974
# Total Timesteps: 475581 Episode Num: 1759 Reward: 1715.6219860975134
# ---------------------------------------
# Average Reward over the Evaluation Step: 1618.548823
# ---------------------------------------
# Total Timesteps: 476581 Episode Num: 1760 Reward: 1593.831786349049
# Total Timesteps: 477581 Episode Num: 1761 Reward: 1732.5072665270002
# Total Timesteps: 478581 Episode Num: 1762 Reward: 1744.5248162100158
# Total Timesteps: 479581 Episode Num: 1763 Reward: 1758.7043591721672
# Total Timesteps: 480581 Episode Num: 1764 Reward: 1621.092449742522
# ---------------------------------------
# Average Reward over the Evaluation Step: 1544.409743
# ---------------------------------------
# Total Timesteps: 481581 Episode Num: 1765 Reward: 1552.3292545464767
# Total Timesteps: 482581 Episode Num: 1766 Reward: 1747.4269458345436
# Total Timesteps: 483581 Episode Num: 1767 Reward: 1679.7290680540632
# Total Timesteps: 484581 Episode Num: 1768 Reward: 1659.8992981480735
# Total Timesteps: 485581 Episode Num: 1769 Reward: 1599.9556142731294
# ---------------------------------------
# Average Reward over the Evaluation Step: 1747.903170
# ---------------------------------------
# Total Timesteps: 486581 Episode Num: 1770 Reward: 1735.541317816408
# Total Timesteps: 487581 Episode Num: 1771 Reward: 1604.0919988964329
# Total Timesteps: 488581 Episode Num: 1772 Reward: 1724.3260225486147
# Total Timesteps: 489581 Episode Num: 1773 Reward: 1690.9699796649668
# Total Timesteps: 490581 Episode Num: 1774 Reward: 1652.7060803723316
# ---------------------------------------
# Average Reward over the Evaluation Step: 1620.743495
# ---------------------------------------
# Total Timesteps: 491581 Episode Num: 1775 Reward: 1602.952246208823
# Total Timesteps: 492581 Episode Num: 1776 Reward: 1760.4459759966728
# Total Timesteps: 493581 Episode Num: 1777 Reward: 1652.948505739981
# Total Timesteps: 494581 Episode Num: 1778 Reward: 1818.0555827942342
# Total Timesteps: 495283 Episode Num: 1779 Reward: 1236.2787106824562
# ---------------------------------------
# Average Reward over the Evaluation Step: 1664.148262
# ---------------------------------------
# Total Timesteps: 496283 Episode Num: 1780 Reward: 1677.4509035351045
# Total Timesteps: 497283 Episode Num: 1781 Reward: 1720.5783738805214
# Total Timesteps: 498283 Episode Num: 1782 Reward: 1764.3289223208521
# Total Timesteps: 499283 Episode Num: 1783 Reward: 1771.6543794188553
# ---------------------------------------
# Average Reward over the Evaluation Step: 1710.339473
# ---------------------------------------

# %% [markdown]
# ## Inference

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x)) 
    return x

class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    # Forward-Propagation on the first Critic Neural Network
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    # Forward-Propagation on the second Critic Neural Network
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)
    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# Selecting the device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Building the whole Training Process into a class

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())
    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())
    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      # Step 4: We sample a batch of transitions (s, s’, a, r) from the memory
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      # Step 5: From the next state s’, the Actor target plays the next action a’
      next_action = self.actor_target(next_state)
      
      # Step 6: We add Gaussian noise to this next action a’ and we clamp it in a range of values supported by the environment
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      # Step 7: The two Critic targets take each the couple (s’, a’) as input and return two Q-values Qt1(s’,a’) and Qt2(s’,a’) as outputs
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      
      # Step 8: We keep the minimum of these two Q-values: min(Qt1, Qt2)
      target_Q = torch.min(target_Q1, target_Q2)
      
      # Step 9: We get the final target of the two Critic models, which is: Qt = r + γ * min(Qt1, Qt2), where γ is the discount factor
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      # Step 10: The two Critic models take each the couple (s, a) as input and return two Q-values Q1(s,a) and Q2(s,a) as outputs
      current_Q1, current_Q2 = self.critic(state, action)
      
      # Step 11: We compute the loss coming from the two Critic models: Critic Loss = MSE_Loss(Q1(s,a), Qt) + MSE_Loss(Q2(s,a), Qt)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      # Step 12: We backpropagate this Critic loss and update the parameters of the two Critic models with a SGD optimizer
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      # Step 13: Once every two iterations, we update our Actor model by performing gradient ascent on the output of the first Critic model
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        # Step 14: Still once every two iterations, we update the weights of the Actor target by polyak averaging
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        # Step 15: Still once every two iterations, we update the weights of the Critic target by polyak averaging
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  # Making a save method to save a trained model
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  # Making a load method to load a pre-trained model
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

def evaluate_policy(policy, eval_episodes=10):
  avg_reward = 0.
  for _ in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

env_name = "Walker2DBulletEnv-v0"
seed = 0

file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")

eval_episodes = 10
save_env_vid = True
env = gym.make(env_name)
max_episode_steps = env._max_episode_steps
if save_env_vid:
  env = wrappers.Monitor(env, monitor_dir, force = True)
  env.reset()
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])
policy = TD3(state_dim, action_dim, max_action)
policy.load(file_name, './pytorch_models/')
_ = evaluate_policy(policy, eval_episodes=eval_episodes)
# Out:
# ---------------------------------------
# Settings: TD3_Walker2DBulletEnv-v0_0
# ---------------------------------------
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------
# Average Reward over the Evaluation Step: 1707.771999
# ---------------------------------------
